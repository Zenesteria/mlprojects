# %%
import pandas 
from pandas import DataFrame
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('DATASET/cost_revenue_cleaned.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  production_revenue_usd
# count           5.034000e+03            5.034000e+03
# mean            3.290784e+07            9.515685e+07
# std             4.112589e+07            1.726012e+08
# min             1.100000e+03            2.600000e+01
# 25%             6.000000e+06            7.000000e+06
# 50%             1.900000e+07            3.296202e+07
# 75%             4.200000e+07            1.034471e+08
# max             4.250000e+08            2.783919e+09

# %%
X = DataFrame(data, columns=['production_budget_usd'])
y = DataFrame(data, columns=['production_revenue_usd'])

# %%
plt.figure(figsize=(10, 4))
plt.scatter(X, y, alpha=0.3)
plt.title('Film cost vs Global revenue')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.xlabel('BUDGET IN USD')
plt.ylabel('REVENUE IN USD')
plt.show()

# %%
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Gradient Coefficient

# %%
regression.coef_
# Out:
# array([[3.11150918]])

# %%
regression.intercept_
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(10, 4))
plt.scatter(X, y, alpha=0.3)
plt.plot(X, regression.predict(X), color='red', linewidth=4, alpha=0.4)
plt.title('Film cost vs Global revenue')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.xlabel('BUDGET IN USD')
plt.ylabel('REVENUE IN USD')
plt.show()
